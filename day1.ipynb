# %%
#variables
a="deemah"
print(type(a))
# Out:
# <class 'str'>

# %%
a = 5
b = 3
sum = a + b
print(sum)
# Out:
# 8

# %%
a=10
b=10
print(a+b)
# Out:
# 20

# %%
# This is a single line comment
print("hello python")
# Out:
# hello python

# %%
# using ''' we can comment multiline ex:
'''a=5
b=10
print(a+b)'''
# Out:
# 8

# %%
# legal variable
name = "Ram"
age = 21
_total = 50
student1 = "Arun"

print(name)
print(age)
# Out:
# Ram
# 21

# %%
# illegal variable
1name = "Ram"   # starts with number
my name = "Sam" # space not allowed
class = 10      # keyword
# Out:
# <class 'str'>

# %%
#multiple values
a, b, c = 10, 20, 30
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
#static value
age = 20
name = "Ram"

print(age)
print(name)
# Out:
# 20
# Ram

# %%
#dynamic value
name = input("Enter your name: ")
age = input("Enter your age: ")

print(name)
print(age)
